# %% [markdown]
# ## Dependencies

# %%
import cv2
import numpy as np
import pandas as pd
import os
import time
import mediapipe as mp
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.utils import to_categorical  # covert stuff to one-hot encoding
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input
from tensorflow.keras.callbacks import TensorBoard
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %% [markdown]
# ## Constants

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# Path for exported data, numpy arrays
DATA_PATH = os.path.join(os.getcwd(), "data")
DATASET_PATH = "dataset/"

# Number of frames for each video
sequence_length = 30

# %% [markdown]
# ## WLASL Data Parsing

# %%
def get_videos_ids(json_list):
    """
    function to check if the video id is available in the dataset
    and return the viedos ids of the current instance

    input: instance json list
    output: list of videos_ids

    """
    videos_list = []
    for ins in json_list:
        video_id = ins["video_id"]
        if os.path.exists(f"{DATASET_PATH}videos/{video_id}.mp4"):
            videos_list.append(video_id)
    return videos_list


def get_json_features(json_list):
    """
    function to check if the video id is available in the dataset
    and return the viedos ids and url or any other featrue of the current instance

    input: instance json list
    output: list of videos_ids

    """
    videos_ids = []
    videos_urls = []
    for ins in json_list:
        video_id = ins["video_id"]
        video_url = ins["url"]
        if os.path.exists(f"{DATASET_PATH}videos/{video_id}.mp4"):
            videos_ids.append(video_id)
            videos_urls.append(video_url)
    return videos_ids, videos_urls

wlas_df = pd.read_json(DATASET_PATH + "WLASL_v0.3.json")
wlas_df["videos_ids"] = wlas_df["instances"].apply(get_videos_ids)

features_df = pd.DataFrame(columns=["gloss", "video_id", "url"])
for row in wlas_df.iterrows():
    ids, urls = get_json_features(row[1][1])
    word = [row[1][0]] * len(ids)
    df = pd.DataFrame(list(zip(word, ids, urls)), columns=features_df.columns)
    # features_df = features_df.append(df, ignore_index=True)
    features_df = pd.concat([features_df, df], ignore_index=True)
    features_df.index.name = "index"

# %% [markdown]
# ## Mediapipe Methods

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Colour conversion
    image.flags.writeable = False  # Image is not writeable
    results = model.process(
        image
    )  # Make prediction -> Go read about that for diss ,it basically tries to find the landmarks
    image.flags.writeable = True  # Image is now writeable
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    return image, results

def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(
        image,
        results.face_landmarks,
        mp_holistic.FACEMESH_CONTOURS,
        mp_drawing.DrawingSpec(color=(0, 0, 255), thickness=1, circle_radius=1),
        mp_drawing.DrawingSpec(color=(0, 255, 0), thickness=1, circle_radius=1),
    )
    mp_drawing.draw_landmarks(
        image,
        results.left_hand_landmarks,
        mp_holistic.HAND_CONNECTIONS,
        mp_drawing.DrawingSpec(color=(0, 0, 255), thickness=2, circle_radius=2),
        mp_drawing.DrawingSpec(color=(0, 255, 0), thickness=2),
    )
    mp_drawing.draw_landmarks(
        image,
        results.right_hand_landmarks,
        mp_holistic.HAND_CONNECTIONS,
        mp_drawing.DrawingSpec(color=(0, 0, 255), thickness=2, circle_radius=2),
        mp_drawing.DrawingSpec(color=(0, 255, 0), thickness=2),
    )
    mp_drawing.draw_landmarks(
        image,
        results.pose_landmarks,
        mp_holistic.POSE_CONNECTIONS,
        mp_drawing.DrawingSpec(color=(0, 0, 255), thickness=1, circle_radius=1),
        mp_drawing.DrawingSpec(color=(0, 255, 0), thickness=2, circle_radius=1),
    )
def extract_keypoints(results):
    pose = (
        np.array(
            [
                [res.x, res.y, res.z, res.visibility]
                for res in results.pose_landmarks.landmark
            ]
        ).flatten()
        if results.pose_landmarks
        else np.zeros(33 * 4)
    )
    face = (
        np.array(
            [[res.x, res.y, res.z] for res in results.face_landmarks.landmark]
        ).flatten()
        if results.face_landmarks
        else np.zeros(468 * 3)
    )
    lh = (
        np.array(
            [[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]
        ).flatten()
        if results.left_hand_landmarks
        else np.zeros(21 * 3)
    )
    rh = (
        np.array(
            [[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]
        ).flatten()
        if results.right_hand_landmarks
        else np.zeros(21 * 3)
    )
    return np.concatenate([pose, face, lh, rh])

# %% [markdown]
# ## Live Data Capturing

# %%
count = 0
limit = 100

for row in features_df.iterrows():

    # Iterate through fixed number of data
    count += 1
    if count > limit:
        break

    # Get the sign name, video id, and path
    name = row[1][0]
    video_id = row[1][1]
    path = DATASET_PATH + "videos/" + video_id + ".mp4"

    cap = cv2.VideoCapture(path)

    # Access mediapipe model
    with mp_holistic.Holistic(
        min_detection_confidence=0.4,
        min_tracking_confidence=0.4,
        model_complexity=1,
    ) as holistic:
        last_frame = None
        for frame_num in range(sequence_length):

            # Read feed
            # ret is return value, frame is the image
            ret, frame = cap.read()

            # Pad remaining frames with last frame
            if ret:
                last_frame = frame
            else:
                frame = last_frame

            # Make detections
            image, results = mediapipe_detection(frame, holistic)
            draw_landmarks(image, results)
            keypoints = extract_keypoints(results)

            # Save keypoints
            npy_path = os.path.join(DATA_PATH, name, video_id, str(frame_num))
            os.makedirs(os.path.join(DATA_PATH, name, video_id), exist_ok=True)
            np.save(npy_path, keypoints)

            # Display current frames, comment out if needed
            cv2.imshow("Keypoints", image)

            # Break using q
            if cv2.waitKey(10) & 0xFF == ord("q"):
                cap.release()
                cv2.destroyAllWindows()
                break
        

print("Data created successfully!")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [39], line 38
#      35     frame = last_frame
#      37 # Make detections
# ---> 38 image, results = mediapipe_detection(frame, holistic)
#      39 draw_landmarks(image, results)
#      40 keypoints = extract_keypoints(results)
#
# Cell In [28], line 4, in mediapipe_detection(image, model)
#       2 image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Colour conversion
#       3 image.flags.writeable = False  # Image is not writeable
# ----> 4 results = model.process(
#       5     image
#       6 )  # Make prediction -> Go read about that for diss ,it basically tries to find the landmarks
#       7 image.flags.writeable = True  # Image is now writeable
#       8 image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
#
# File c:\Python310\lib\site-packages\mediapipe\python\solutions\holistic.py:160, in Holistic.process(self, image)
#     136 def process(self, image: np.ndarray) -> NamedTuple:
#     137   """Processes an RGB image and returns the pose landmarks, left and right hand landmarks, and face landmarks on the most prominent person detected.
#     138
#     139   Args:
#    (...)
#     157          "enable_segmentation" is set to true.
#     158   """
# --> 160   results = super().process(input_data={'image': image})
#     161   if results.pose_landmarks:  # pytype: disable=attribute-error
#     162     for landmark in results.pose_landmarks.landmark:  # pytype: disable=attribute-error
#
# File c:\Python310\lib\site-packages\mediapipe\python\solution_base.py:366, in SolutionBase.process(self, input_data)
#     360   else:
#     361     self._graph.add_packet_to_input_stream(
#     362         stream=stream_name,
#     363         packet=self._make_packet(input_stream_type,
#     364                                  data).at(self._simulated_timestamp))
# --> 366 self._graph.wait_until_idle()
#     367 # Create a NamedTuple object where the field names are mapping to the graph
#     368 # output stream names.
#     369 solution_outputs = collections.namedtuple(
#     370     'SolutionOutputs', self._output_stream_type_info.keys())
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Data Loading

# %%
sequences, labels = [], []
label_map = {label: num for num, label in enumerate(os.listdir(DATA_PATH))}
signs = []

for sign in os.listdir(DATA_PATH):
    signs.append(sign)
    for sequence in os.listdir(os.path.join(DATA_PATH, sign)):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(
                os.path.join(DATA_PATH, sign, str(sequence), f"{frame_num}.npy")
            )
            window.append(res)
        sequences.append(window)
        labels.append(label_map[sign])

signs = np.array(signs)

# %%
# Test

sequences, labels = [], []
label_map = {label: num for num, label in enumerate(os.listdir(DATA_PATH))}
signs = []

for sign in os.listdir(DATA_PATH):
    signs.append(sign)
    for sequence in os.listdir(os.path.join(DATA_PATH, sign)):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(
                os.path.join(DATA_PATH, sign, str(sequence), f"{frame_num}.npy")
            )
            sequences.append(res)
            labels.append(label_map[sign])

signs = np.array(signs)

# %%
X = np.array(sequences)
y = to_categorical(labels).astype(int)  # why do we do onehot encoding here?

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

log_dir = os.path.join("Logs")
tb_callback = TensorBoard(log_dir=log_dir)

# %%
X.shape
# Out:
# (2460, 1662)

# %% [markdown]
# ## Model Training

# %%
model = Sequential()  # look at sequential video mentionned at 1:38:00
model.add(
    LSTM(
        64,
        return_sequences=True,
        activation="relu",
        input_shape=(sequence_length, 1662),
    )
)
model.add(Dropout(0.2))
model.add(LSTM(128, return_sequences=True, activation="relu"))
model.add(
    LSTM(64, return_sequences=False, activation="relu")
)  # set to false because we are not returning sequences as next layer is dense
model.add(Dropout(0.4))
model.add(Dense(64, activation="relu", kernel_initializer='he_normal'))
model.add(Dense(32, activation="relu", kernel_initializer='he_normal'))
model.add(Dense(signs.shape[0], activation="softmax"))  # look at argmax logic

model.compile(
    optimizer="adam", loss="categorical_crossentropy", metrics=["categorical_accuracy"]
)

model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_9 (LSTM)               (None, 30, 64)            442112
#
#  dropout_12 (Dropout)        (None, 30, 64)            0
#
#  lstm_10 (LSTM)              (None, 30, 128)           98816
#
#  lstm_11 (LSTM)              (None, 64)                49408
#
#  dropout_13 (Dropout)        (None, 64)                0
#
#  dense_16 (Dense)            (None, 64)                4160
#
#  dense_17 (Dense)            (None, 32)                2080
#
#  dense_18 (Dense)            (None, 6)                 198
#
# =================================================================
# Total params: 596,774
# Trainable params: 596,774
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Test

model = Sequential([
    Input((1662,)),
    Dropout(0.2),
    Dense(20, activation='relu'),
    Dropout(0.4),
    Dense(10, activation='relu'),
    Dense(signs.shape[0], activation='softmax')
])

model.summary()
model.compile(
    optimizer="adam", loss="categorical_crossentropy", metrics=["categorical_accuracy"]
)
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dropout_20 (Dropout)        (None, 1662)              0
#
#  dense_28 (Dense)            (None, 20)                33260
#
#  dropout_21 (Dropout)        (None, 20)                0
#
#  dense_29 (Dense)            (None, 10)                210
#
#  dense_30 (Dense)            (None, 6)                 66
#
# =================================================================
# Total params: 33,536
# Trainable params: 33,536
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train, epochs=1000, callbacks=[tb_callback])
model.summary()
model.save("model.h5")
# Out:
# Epoch 1/1000
# 62/62 [==============================] - 1s 2ms/step - loss: 1.7612 - categorical_accuracy: 0.2063
# Epoch 2/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.7126 - categorical_accuracy: 0.2246
# Epoch 3/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.6732 - categorical_accuracy: 0.2454
# Epoch 4/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.6544 - categorical_accuracy: 0.2541
# Epoch 5/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.6458 - categorical_accuracy: 0.2602
# Epoch 6/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.6352 - categorical_accuracy: 0.2688
# Epoch 7/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.6267 - categorical_accuracy: 0.2744
# Epoch 8/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.6280 - categorical_accuracy: 0.2688
# Epoch 9/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.6325 - categorical_accuracy: 0.2622
# Epoch 10/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.6254 - categorical_accuracy: 0.2622
# Epoch 11/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.6164 - categorical_accuracy: 0.2790
# Epoch 12/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.6205 - categorical_accuracy: 0.2749
# Epoch 13/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.6226 - categorical_accuracy: 0.2652
# Epoch 14/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.6199 - categorical_accuracy: 0.2602
# Epoch 15/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.6226 - categorical_accuracy: 0.2698
# Epoch 16/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.6212 - categorical_accuracy: 0.2703
# Epoch 17/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.6174 - categorical_accuracy: 0.2754
# Epoch 18/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.6041 - categorical_accuracy: 0.2886
# Epoch 19/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.6015 - categorical_accuracy: 0.2800
# Epoch 20/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5929 - categorical_accuracy: 0.2840
# Epoch 21/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5818 - categorical_accuracy: 0.3034
# Epoch 22/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5911 - categorical_accuracy: 0.3059
# Epoch 23/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5927 - categorical_accuracy: 0.2932
# Epoch 24/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.5800 - categorical_accuracy: 0.3161
# Epoch 25/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5843 - categorical_accuracy: 0.3034
# Epoch 26/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5786 - categorical_accuracy: 0.3110
# Epoch 27/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5806 - categorical_accuracy: 0.3105
# Epoch 28/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5652 - categorical_accuracy: 0.3150
# Epoch 29/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5576 - categorical_accuracy: 0.3211
# Epoch 30/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5654 - categorical_accuracy: 0.3145
# Epoch 31/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5622 - categorical_accuracy: 0.3196
# Epoch 32/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5651 - categorical_accuracy: 0.3166
# Epoch 33/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5630 - categorical_accuracy: 0.3181
# Epoch 34/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5649 - categorical_accuracy: 0.3044
# Epoch 35/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5552 - categorical_accuracy: 0.3323
# Epoch 36/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.5401 - categorical_accuracy: 0.3455
# Epoch 37/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5370 - categorical_accuracy: 0.3308
# Epoch 38/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5434 - categorical_accuracy: 0.3252
# Epoch 39/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5542 - categorical_accuracy: 0.3354
# Epoch 40/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5370 - categorical_accuracy: 0.3333
# Epoch 41/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5426 - categorical_accuracy: 0.3257
# Epoch 42/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5410 - categorical_accuracy: 0.3333
# Epoch 43/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5314 - categorical_accuracy: 0.3394
# Epoch 44/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5320 - categorical_accuracy: 0.3374
# Epoch 45/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5176 - categorical_accuracy: 0.3415
# Epoch 46/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5415 - categorical_accuracy: 0.3288
# Epoch 47/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5353 - categorical_accuracy: 0.3323
# Epoch 48/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5500 - categorical_accuracy: 0.3206
# Epoch 49/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5270 - categorical_accuracy: 0.3506
# Epoch 50/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5221 - categorical_accuracy: 0.3471
# Epoch 51/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5177 - categorical_accuracy: 0.3496
# Epoch 52/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5255 - categorical_accuracy: 0.3430
# Epoch 53/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5166 - categorical_accuracy: 0.3481
# Epoch 54/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5133 - categorical_accuracy: 0.3486
# Epoch 55/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5125 - categorical_accuracy: 0.3374
# Epoch 56/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5153 - categorical_accuracy: 0.3496
# Epoch 57/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5249 - categorical_accuracy: 0.3333
# Epoch 58/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5173 - categorical_accuracy: 0.3404
# Epoch 59/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5120 - categorical_accuracy: 0.3491
# Epoch 60/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4951 - categorical_accuracy: 0.3455
# Epoch 61/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5237 - categorical_accuracy: 0.3349
# Epoch 62/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5186 - categorical_accuracy: 0.3410
# Epoch 63/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5242 - categorical_accuracy: 0.3247
# Epoch 64/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5364 - categorical_accuracy: 0.3425
# Epoch 65/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4951 - categorical_accuracy: 0.3465
# Epoch 66/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5012 - categorical_accuracy: 0.3445
# Epoch 67/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4880 - categorical_accuracy: 0.3511
# Epoch 68/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4899 - categorical_accuracy: 0.3491
# Epoch 69/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4938 - categorical_accuracy: 0.3613
# Epoch 70/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4971 - categorical_accuracy: 0.3537
# Epoch 71/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5064 - categorical_accuracy: 0.3638
# Epoch 72/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5042 - categorical_accuracy: 0.3486
# Epoch 73/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5100 - categorical_accuracy: 0.3476
# Epoch 74/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5022 - categorical_accuracy: 0.3471
# Epoch 75/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5021 - categorical_accuracy: 0.3476
# Epoch 76/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4984 - categorical_accuracy: 0.3486
# Epoch 77/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4996 - categorical_accuracy: 0.3542
# Epoch 78/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4994 - categorical_accuracy: 0.3562
# Epoch 79/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5049 - categorical_accuracy: 0.3450
# Epoch 80/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5078 - categorical_accuracy: 0.3425
# Epoch 81/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5065 - categorical_accuracy: 0.3410
# Epoch 82/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5054 - categorical_accuracy: 0.3465
# Epoch 83/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4739 - categorical_accuracy: 0.3623
# Epoch 84/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5169 - categorical_accuracy: 0.3425
# Epoch 85/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5066 - categorical_accuracy: 0.3430
# Epoch 86/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5043 - categorical_accuracy: 0.3440
# Epoch 87/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4913 - categorical_accuracy: 0.3486
# Epoch 88/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5057 - categorical_accuracy: 0.3486
# Epoch 89/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.4951 - categorical_accuracy: 0.3471
# Epoch 90/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4843 - categorical_accuracy: 0.3552
# Epoch 91/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5015 - categorical_accuracy: 0.3557
# Epoch 92/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4931 - categorical_accuracy: 0.3526
# Epoch 93/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4825 - categorical_accuracy: 0.3537
# Epoch 94/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5081 - categorical_accuracy: 0.3501
# Epoch 95/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5053 - categorical_accuracy: 0.3542
# Epoch 96/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5013 - categorical_accuracy: 0.3430
# Epoch 97/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4926 - categorical_accuracy: 0.3582
# Epoch 98/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4869 - categorical_accuracy: 0.3476
# Epoch 99/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4768 - categorical_accuracy: 0.3562
# Epoch 100/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4979 - categorical_accuracy: 0.3491
# Epoch 101/1000
# 62/62 [==============================] - 0s 1ms/step - loss: 1.4786 - categorical_accuracy: 0.3486
# Epoch 102/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4636 - categorical_accuracy: 0.3679
# Epoch 103/1000
# 62/62 [==============================] - 0s 1ms/step - loss: 1.4925 - categorical_accuracy: 0.3547
# Epoch 104/1000
# 62/62 [==============================] - 0s 1ms/step - loss: 1.5034 - categorical_accuracy: 0.3521
# Epoch 105/1000
# 62/62 [==============================] - 0s 1ms/step - loss: 1.4853 - categorical_accuracy: 0.3557
# Epoch 106/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5050 - categorical_accuracy: 0.3410
# Epoch 107/1000
# 62/62 [==============================] - 0s 1ms/step - loss: 1.4763 - categorical_accuracy: 0.3598
# Epoch 108/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5001 - categorical_accuracy: 0.3506
# Epoch 109/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4865 - categorical_accuracy: 0.3445
# Epoch 110/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4836 - categorical_accuracy: 0.3628
# Epoch 111/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4902 - categorical_accuracy: 0.3440
# Epoch 112/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4744 - categorical_accuracy: 0.3638
# Epoch 113/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4858 - categorical_accuracy: 0.3562
# Epoch 114/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4734 - categorical_accuracy: 0.3613
# Epoch 115/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4951 - categorical_accuracy: 0.3577
# Epoch 116/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4794 - categorical_accuracy: 0.3491
# Epoch 117/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4884 - categorical_accuracy: 0.3572
# Epoch 118/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4979 - categorical_accuracy: 0.3608
# Epoch 119/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4853 - categorical_accuracy: 0.3577
# Epoch 120/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4911 - categorical_accuracy: 0.3689
# Epoch 121/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4831 - categorical_accuracy: 0.3592
# Epoch 122/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4838 - categorical_accuracy: 0.3643
# Epoch 123/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4716 - categorical_accuracy: 0.3633
# Epoch 124/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4762 - categorical_accuracy: 0.3537
# Epoch 125/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4813 - categorical_accuracy: 0.3598
# Epoch 126/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4918 - categorical_accuracy: 0.3557
# Epoch 127/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4802 - categorical_accuracy: 0.3582
# Epoch 128/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4815 - categorical_accuracy: 0.3567
# Epoch 129/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4781 - categorical_accuracy: 0.3633
# Epoch 130/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4791 - categorical_accuracy: 0.3592
# Epoch 131/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4830 - categorical_accuracy: 0.3486
# Epoch 132/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4854 - categorical_accuracy: 0.3664
# Epoch 133/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4652 - categorical_accuracy: 0.3638
# Epoch 134/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4854 - categorical_accuracy: 0.3577
# Epoch 135/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4775 - categorical_accuracy: 0.3613
# Epoch 136/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4797 - categorical_accuracy: 0.3532
# Epoch 137/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4898 - categorical_accuracy: 0.3592
# Epoch 138/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4743 - categorical_accuracy: 0.3608
# Epoch 139/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4768 - categorical_accuracy: 0.3643
# Epoch 140/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4693 - categorical_accuracy: 0.3633
# Epoch 141/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4465 - categorical_accuracy: 0.3714
# Epoch 142/1000
# 62/62 [==============================] - 0s 1ms/step - loss: 1.4822 - categorical_accuracy: 0.3471
# Epoch 143/1000
# 62/62 [==============================] - 0s 1ms/step - loss: 1.4935 - categorical_accuracy: 0.3577
# Epoch 144/1000
# 62/62 [==============================] - 0s 1ms/step - loss: 1.4793 - categorical_accuracy: 0.3674
# Epoch 145/1000
# 62/62 [==============================] - 0s 1ms/step - loss: 1.4807 - categorical_accuracy: 0.3608
# Epoch 146/1000
# 62/62 [==============================] - 0s 1ms/step - loss: 1.4884 - categorical_accuracy: 0.3450
# Epoch 147/1000
# 62/62 [==============================] - 0s 1ms/step - loss: 1.4809 - categorical_accuracy: 0.3623
# Epoch 148/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4614 - categorical_accuracy: 0.3775
# Epoch 149/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4651 - categorical_accuracy: 0.3633
# Epoch 150/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4865 - categorical_accuracy: 0.3577
# Epoch 151/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5017 - categorical_accuracy: 0.3460
# Epoch 152/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4979 - categorical_accuracy: 0.3501
# Epoch 153/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4652 - categorical_accuracy: 0.3674
# Epoch 154/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4766 - categorical_accuracy: 0.3567
# Epoch 155/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4621 - categorical_accuracy: 0.3709
# Epoch 156/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4710 - categorical_accuracy: 0.3623
# Epoch 157/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4823 - categorical_accuracy: 0.3598
# Epoch 158/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4842 - categorical_accuracy: 0.3526
# Epoch 159/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4636 - categorical_accuracy: 0.3750
# Epoch 160/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4771 - categorical_accuracy: 0.3699
# Epoch 161/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4851 - categorical_accuracy: 0.3633
# Epoch 162/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4870 - categorical_accuracy: 0.3537
# Epoch 163/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4901 - categorical_accuracy: 0.3521
# Epoch 164/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4523 - categorical_accuracy: 0.3826
# Epoch 165/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4738 - categorical_accuracy: 0.3674
# Epoch 166/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4806 - categorical_accuracy: 0.3623
# Epoch 167/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4713 - categorical_accuracy: 0.3669
# Epoch 168/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4669 - categorical_accuracy: 0.3775
# Epoch 169/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4767 - categorical_accuracy: 0.3486
# Epoch 170/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4536 - categorical_accuracy: 0.3791
# Epoch 171/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4710 - categorical_accuracy: 0.3628
# Epoch 172/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4623 - categorical_accuracy: 0.3740
# Epoch 173/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4648 - categorical_accuracy: 0.3750
# Epoch 174/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4781 - categorical_accuracy: 0.3592
# Epoch 175/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4831 - categorical_accuracy: 0.3730
# Epoch 176/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4541 - categorical_accuracy: 0.3755
# Epoch 177/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4671 - categorical_accuracy: 0.3679
# Epoch 178/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4782 - categorical_accuracy: 0.3725
# Epoch 179/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4617 - categorical_accuracy: 0.3720
# Epoch 180/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4593 - categorical_accuracy: 0.3755
# Epoch 181/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4589 - categorical_accuracy: 0.3745
# Epoch 182/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4565 - categorical_accuracy: 0.3872
# Epoch 183/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5240 - categorical_accuracy: 0.3557
# Epoch 184/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4634 - categorical_accuracy: 0.3720
# Epoch 185/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4670 - categorical_accuracy: 0.3725
# Epoch 186/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4748 - categorical_accuracy: 0.3699
# Epoch 187/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4528 - categorical_accuracy: 0.3938
# Epoch 188/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4789 - categorical_accuracy: 0.3664
# Epoch 189/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4603 - categorical_accuracy: 0.3714
# Epoch 190/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4521 - categorical_accuracy: 0.3847
# Epoch 191/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4684 - categorical_accuracy: 0.3714
# Epoch 192/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4682 - categorical_accuracy: 0.3679
# Epoch 193/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4855 - categorical_accuracy: 0.3643
# Epoch 194/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4599 - categorical_accuracy: 0.3740
# Epoch 195/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4747 - categorical_accuracy: 0.3730
# Epoch 196/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4552 - categorical_accuracy: 0.3918
# Epoch 197/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4475 - categorical_accuracy: 0.3826
# Epoch 198/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4601 - categorical_accuracy: 0.3730
# Epoch 199/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4344 - categorical_accuracy: 0.3968
# Epoch 200/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4723 - categorical_accuracy: 0.3699
# Epoch 201/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4491 - categorical_accuracy: 0.3775
# Epoch 202/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4709 - categorical_accuracy: 0.3841
# Epoch 203/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4604 - categorical_accuracy: 0.3796
# Epoch 204/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4384 - categorical_accuracy: 0.3938
# Epoch 205/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4725 - categorical_accuracy: 0.3786
# Epoch 206/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4651 - categorical_accuracy: 0.3720
# Epoch 207/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4743 - categorical_accuracy: 0.3720
# Epoch 208/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4808 - categorical_accuracy: 0.3648
# Epoch 209/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4968 - categorical_accuracy: 0.3369
# Epoch 210/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4640 - categorical_accuracy: 0.3730
# Epoch 211/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4612 - categorical_accuracy: 0.3831
# Epoch 212/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4534 - categorical_accuracy: 0.3831
# Epoch 213/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4805 - categorical_accuracy: 0.3725
# Epoch 214/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4609 - categorical_accuracy: 0.3786
# Epoch 215/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4783 - categorical_accuracy: 0.3664
# Epoch 216/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4709 - categorical_accuracy: 0.3659
# Epoch 217/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4417 - categorical_accuracy: 0.3948
# Epoch 218/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4672 - categorical_accuracy: 0.3745
# Epoch 219/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4804 - categorical_accuracy: 0.3669
# Epoch 220/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4638 - categorical_accuracy: 0.3750
# Epoch 221/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4768 - categorical_accuracy: 0.3628
# Epoch 222/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4691 - categorical_accuracy: 0.3709
# Epoch 223/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4592 - categorical_accuracy: 0.3714
# Epoch 224/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4597 - categorical_accuracy: 0.3801
# Epoch 225/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4552 - categorical_accuracy: 0.3857
# Epoch 226/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4555 - categorical_accuracy: 0.3780
# Epoch 227/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4467 - categorical_accuracy: 0.3908
# Epoch 228/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4695 - categorical_accuracy: 0.3684
# Epoch 229/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4621 - categorical_accuracy: 0.3811
# Epoch 230/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4643 - categorical_accuracy: 0.3775
# Epoch 231/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4505 - categorical_accuracy: 0.3770
# Epoch 232/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4674 - categorical_accuracy: 0.3750
# Epoch 233/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4654 - categorical_accuracy: 0.3821
# Epoch 234/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4745 - categorical_accuracy: 0.3679
# Epoch 235/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4699 - categorical_accuracy: 0.3684
# Epoch 236/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4493 - categorical_accuracy: 0.3831
# Epoch 237/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4696 - categorical_accuracy: 0.3694
# Epoch 238/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4589 - categorical_accuracy: 0.3755
# Epoch 239/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4657 - categorical_accuracy: 0.3689
# Epoch 240/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4623 - categorical_accuracy: 0.3760
# Epoch 241/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4721 - categorical_accuracy: 0.3730
# Epoch 242/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4696 - categorical_accuracy: 0.3786
# Epoch 243/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4443 - categorical_accuracy: 0.3847
# Epoch 244/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4583 - categorical_accuracy: 0.3908
# Epoch 245/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4652 - categorical_accuracy: 0.3745
# Epoch 246/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4772 - categorical_accuracy: 0.3770
# Epoch 247/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4542 - categorical_accuracy: 0.3786
# Epoch 248/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4593 - categorical_accuracy: 0.3745
# Epoch 249/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4487 - categorical_accuracy: 0.3923
# Epoch 250/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4703 - categorical_accuracy: 0.3786
# Epoch 251/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4563 - categorical_accuracy: 0.3806
# Epoch 252/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4661 - categorical_accuracy: 0.3714
# Epoch 253/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4653 - categorical_accuracy: 0.3775
# Epoch 254/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4376 - categorical_accuracy: 0.3943
# Epoch 255/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4574 - categorical_accuracy: 0.3826
# Epoch 256/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.4644 - categorical_accuracy: 0.3775
# Epoch 257/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4722 - categorical_accuracy: 0.3801
# Epoch 258/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4629 - categorical_accuracy: 0.3755
# Epoch 259/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4635 - categorical_accuracy: 0.3826
# Epoch 260/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4699 - categorical_accuracy: 0.3720
# Epoch 261/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4570 - categorical_accuracy: 0.3867
# Epoch 262/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4540 - categorical_accuracy: 0.3796
# Epoch 263/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4488 - categorical_accuracy: 0.3836
# Epoch 264/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4476 - categorical_accuracy: 0.3872
# Epoch 265/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4484 - categorical_accuracy: 0.3974
# Epoch 266/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4490 - categorical_accuracy: 0.3867
# Epoch 267/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4429 - categorical_accuracy: 0.3928
# Epoch 268/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4646 - categorical_accuracy: 0.3882
# Epoch 269/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.4872 - categorical_accuracy: 0.3633
# Epoch 270/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4602 - categorical_accuracy: 0.3882
# Epoch 271/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4499 - categorical_accuracy: 0.3841
# Epoch 272/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4553 - categorical_accuracy: 0.3811
# Epoch 273/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4239 - categorical_accuracy: 0.4040
# Epoch 274/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4483 - categorical_accuracy: 0.3801
# Epoch 275/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4447 - categorical_accuracy: 0.3984
# Epoch 276/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4441 - categorical_accuracy: 0.3897
# Epoch 277/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4721 - categorical_accuracy: 0.3704
# Epoch 278/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4510 - categorical_accuracy: 0.3806
# Epoch 279/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4649 - categorical_accuracy: 0.3786
# Epoch 280/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4592 - categorical_accuracy: 0.3923
# Epoch 281/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4474 - categorical_accuracy: 0.3841
# Epoch 282/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4520 - categorical_accuracy: 0.3908
# Epoch 283/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4369 - categorical_accuracy: 0.3979
# Epoch 284/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4469 - categorical_accuracy: 0.3841
# Epoch 285/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4857 - categorical_accuracy: 0.3664
# Epoch 286/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4532 - categorical_accuracy: 0.3791
# Epoch 287/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4641 - categorical_accuracy: 0.3867
# Epoch 288/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4510 - categorical_accuracy: 0.3841
# Epoch 289/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4424 - categorical_accuracy: 0.3852
# Epoch 290/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4458 - categorical_accuracy: 0.3852
# Epoch 291/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.4512 - categorical_accuracy: 0.3791
# Epoch 292/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4389 - categorical_accuracy: 0.3928
# Epoch 293/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4492 - categorical_accuracy: 0.3847
# Epoch 294/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4424 - categorical_accuracy: 0.3933
# Epoch 295/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4367 - categorical_accuracy: 0.3928
# Epoch 296/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4496 - categorical_accuracy: 0.3882
# Epoch 297/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4397 - categorical_accuracy: 0.3974
# Epoch 298/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4548 - categorical_accuracy: 0.3709
# Epoch 299/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4720 - categorical_accuracy: 0.3709
# Epoch 300/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.5068 - categorical_accuracy: 0.3440
# Epoch 301/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4798 - categorical_accuracy: 0.3638
# Epoch 302/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4328 - categorical_accuracy: 0.3948
# Epoch 303/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4631 - categorical_accuracy: 0.3806
# Epoch 304/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4629 - categorical_accuracy: 0.3872
# Epoch 305/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4549 - categorical_accuracy: 0.3821
# Epoch 306/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4535 - categorical_accuracy: 0.3872
# Epoch 307/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4655 - categorical_accuracy: 0.3847
# Epoch 308/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4614 - categorical_accuracy: 0.3679
# Epoch 309/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4604 - categorical_accuracy: 0.3765
# Epoch 310/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4579 - categorical_accuracy: 0.3643
# Epoch 311/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4417 - categorical_accuracy: 0.3801
# Epoch 312/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4678 - categorical_accuracy: 0.3714
# Epoch 313/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4480 - categorical_accuracy: 0.3862
# Epoch 314/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4391 - categorical_accuracy: 0.3887
# Epoch 315/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4564 - categorical_accuracy: 0.3852
# Epoch 316/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4364 - categorical_accuracy: 0.3953
# Epoch 317/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4364 - categorical_accuracy: 0.3867
# Epoch 318/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4347 - categorical_accuracy: 0.3852
# Epoch 319/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4497 - categorical_accuracy: 0.3806
# Epoch 320/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4640 - categorical_accuracy: 0.3770
# Epoch 321/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4509 - categorical_accuracy: 0.3831
# Epoch 322/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4370 - categorical_accuracy: 0.3897
# Epoch 323/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4550 - categorical_accuracy: 0.3882
# Epoch 324/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4559 - categorical_accuracy: 0.3831
# Epoch 325/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4381 - categorical_accuracy: 0.3928
# Epoch 326/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4486 - categorical_accuracy: 0.3892
# Epoch 327/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4669 - categorical_accuracy: 0.3760
# Epoch 328/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4726 - categorical_accuracy: 0.3725
# Epoch 329/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4570 - categorical_accuracy: 0.3877
# Epoch 330/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.4679 - categorical_accuracy: 0.3796
# Epoch 331/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.4489 - categorical_accuracy: 0.3852
# Epoch 332/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4659 - categorical_accuracy: 0.3801
# Epoch 333/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.4302 - categorical_accuracy: 0.3821
# Epoch 334/1000
# 62/62 [==============================] - 0s 4ms/step - loss: 1.4377 - categorical_accuracy: 0.3938
# Epoch 335/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4578 - categorical_accuracy: 0.3857
# Epoch 336/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4521 - categorical_accuracy: 0.3897
# Epoch 337/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4543 - categorical_accuracy: 0.3750
# Epoch 338/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4608 - categorical_accuracy: 0.3816
# Epoch 339/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4411 - categorical_accuracy: 0.3918
# Epoch 340/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4447 - categorical_accuracy: 0.3882
# Epoch 341/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4506 - categorical_accuracy: 0.3801
# Epoch 342/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4631 - categorical_accuracy: 0.3801
# Epoch 343/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.4387 - categorical_accuracy: 0.3867
# Epoch 344/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4376 - categorical_accuracy: 0.3984
# Epoch 345/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.4549 - categorical_accuracy: 0.3775
# Epoch 346/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4440 - categorical_accuracy: 0.3862
# Epoch 347/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.4473 - categorical_accuracy: 0.3816
# Epoch 348/1000
# 62/62 [==============================] - 0s 4ms/step - loss: 1.4589 - categorical_accuracy: 0.3806
# Epoch 349/1000
# 62/62 [==============================] - 0s 6ms/step - loss: 1.4246 - categorical_accuracy: 0.4004
# Epoch 350/1000
# 62/62 [==============================] - 0s 5ms/step - loss: 1.4710 - categorical_accuracy: 0.3897
# Epoch 351/1000
# 62/62 [==============================] - 0s 4ms/step - loss: 1.4517 - categorical_accuracy: 0.3847
# Epoch 352/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.4438 - categorical_accuracy: 0.3948
# Epoch 353/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4224 - categorical_accuracy: 0.4050
# Epoch 354/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4617 - categorical_accuracy: 0.3770
# Epoch 355/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4591 - categorical_accuracy: 0.3775
# Epoch 356/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4524 - categorical_accuracy: 0.3755
# Epoch 357/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4387 - categorical_accuracy: 0.3882
# Epoch 358/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4392 - categorical_accuracy: 0.4035
# Epoch 359/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.4450 - categorical_accuracy: 0.3908
# Epoch 360/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4542 - categorical_accuracy: 0.3877
# Epoch 361/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4299 - categorical_accuracy: 0.3882
# Epoch 362/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4553 - categorical_accuracy: 0.3796
# Epoch 363/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.4450 - categorical_accuracy: 0.3918
# Epoch 364/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.4460 - categorical_accuracy: 0.3775
# Epoch 365/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.4502 - categorical_accuracy: 0.3806
# Epoch 366/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.4333 - categorical_accuracy: 0.3984
# Epoch 367/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4304 - categorical_accuracy: 0.3953
# Epoch 368/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.4425 - categorical_accuracy: 0.3938
# Epoch 369/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.4554 - categorical_accuracy: 0.3877
# Epoch 370/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.4369 - categorical_accuracy: 0.3877
# Epoch 371/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.4453 - categorical_accuracy: 0.3811
# Epoch 372/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.4412 - categorical_accuracy: 0.3908
# Epoch 373/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4588 - categorical_accuracy: 0.3775
# Epoch 374/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.4434 - categorical_accuracy: 0.3913
# Epoch 375/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4412 - categorical_accuracy: 0.3994
# Epoch 376/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4330 - categorical_accuracy: 0.3953
# Epoch 377/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4585 - categorical_accuracy: 0.3857
# Epoch 378/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.4543 - categorical_accuracy: 0.3862
# Epoch 379/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4542 - categorical_accuracy: 0.3847
# Epoch 380/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.4536 - categorical_accuracy: 0.3902
# Epoch 381/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.4520 - categorical_accuracy: 0.3902
# Epoch 382/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.4592 - categorical_accuracy: 0.3669
# Epoch 383/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4404 - categorical_accuracy: 0.3867
# Epoch 384/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.4468 - categorical_accuracy: 0.3908
# Epoch 385/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.4636 - categorical_accuracy: 0.3679
# Epoch 386/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4224 - categorical_accuracy: 0.3918
# Epoch 387/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4647 - categorical_accuracy: 0.3765
# Epoch 388/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4485 - categorical_accuracy: 0.3841
# Epoch 389/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4537 - categorical_accuracy: 0.3811
# Epoch 390/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.4444 - categorical_accuracy: 0.3806
# Epoch 391/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.4372 - categorical_accuracy: 0.3841
# Epoch 392/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.4266 - categorical_accuracy: 0.3999
# Epoch 393/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4445 - categorical_accuracy: 0.3938
# Epoch 394/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.4690 - categorical_accuracy: 0.3780
# Epoch 395/1000
# 62/62 [==============================] - 0s 4ms/step - loss: 1.4422 - categorical_accuracy: 0.3862
# Epoch 396/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.4452 - categorical_accuracy: 0.3841
# Epoch 397/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.4487 - categorical_accuracy: 0.3826
# Epoch 398/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.4628 - categorical_accuracy: 0.3745
# Epoch 399/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.4276 - categorical_accuracy: 0.3867
# Epoch 400/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4405 - categorical_accuracy: 0.3897
# Epoch 401/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4371 - categorical_accuracy: 0.3974
# Epoch 402/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4477 - categorical_accuracy: 0.3831
# Epoch 403/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4196 - categorical_accuracy: 0.4035
# Epoch 404/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4440 - categorical_accuracy: 0.3953
# Epoch 405/1000
# 62/62 [==============================] - 0s 4ms/step - loss: 1.4622 - categorical_accuracy: 0.3770
# Epoch 406/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4499 - categorical_accuracy: 0.3801
# Epoch 407/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4525 - categorical_accuracy: 0.3902
# Epoch 408/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4585 - categorical_accuracy: 0.3725
# Epoch 409/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4321 - categorical_accuracy: 0.3887
# Epoch 410/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4484 - categorical_accuracy: 0.3847
# Epoch 411/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4559 - categorical_accuracy: 0.3913
# Epoch 412/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4503 - categorical_accuracy: 0.3821
# Epoch 413/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4457 - categorical_accuracy: 0.3913
# Epoch 414/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4414 - categorical_accuracy: 0.3887
# Epoch 415/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4441 - categorical_accuracy: 0.3791
# Epoch 416/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4454 - categorical_accuracy: 0.3852
# Epoch 417/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4399 - categorical_accuracy: 0.3984
# Epoch 418/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.4397 - categorical_accuracy: 0.3908
# Epoch 419/1000
# 62/62 [==============================] - 0s 4ms/step - loss: 1.4466 - categorical_accuracy: 0.3816
# Epoch 420/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.4322 - categorical_accuracy: 0.3923
# Epoch 421/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.4631 - categorical_accuracy: 0.3821
# Epoch 422/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.4443 - categorical_accuracy: 0.3857
# ...
# Epoch 871/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4190 - categorical_accuracy: 0.3989
# Epoch 872/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.4046 - categorical_accuracy: 0.4085
# Epoch 873/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4105 - categorical_accuracy: 0.3938
# Epoch 874/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4084 - categorical_accuracy: 0.4080
# Epoch 875/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4068 - categorical_accuracy: 0.3984
# Epoch 876/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4454 - categorical_accuracy: 0.3745
# Epoch 877/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4072 - categorical_accuracy: 0.4075
# Epoch 878/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.3960 - categorical_accuracy: 0.3999
# Epoch 879/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4167 - categorical_accuracy: 0.3852
# Epoch 880/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4200 - categorical_accuracy: 0.4029
# Epoch 881/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4225 - categorical_accuracy: 0.4014
# Epoch 882/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4101 - categorical_accuracy: 0.3999
# Epoch 883/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4142 - categorical_accuracy: 0.3892
# Epoch 884/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4061 - categorical_accuracy: 0.4045
# Epoch 885/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.4244 - categorical_accuracy: 0.3974
# Epoch 886/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3866 - categorical_accuracy: 0.4162
# Epoch 887/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3828 - categorical_accuracy: 0.4090
# Epoch 888/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4161 - categorical_accuracy: 0.4029
# Epoch 889/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4085 - categorical_accuracy: 0.3989
# Epoch 890/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.3917 - categorical_accuracy: 0.4131
# Epoch 891/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4263 - categorical_accuracy: 0.3938
# Epoch 892/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4000 - categorical_accuracy: 0.4004
# Epoch 893/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4274 - categorical_accuracy: 0.3821
# Epoch 894/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3826 - categorical_accuracy: 0.4090
# Epoch 895/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.4293 - categorical_accuracy: 0.3938
# Epoch 896/1000
# 62/62 [==============================] - 0s 4ms/step - loss: 1.3951 - categorical_accuracy: 0.4080
# Epoch 897/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.4003 - categorical_accuracy: 0.4060
# Epoch 898/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.4010 - categorical_accuracy: 0.4029
# Epoch 899/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.3869 - categorical_accuracy: 0.4014
# Epoch 900/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.4112 - categorical_accuracy: 0.3989
# Epoch 901/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.3906 - categorical_accuracy: 0.4050
# Epoch 902/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.3847 - categorical_accuracy: 0.4045
# Epoch 903/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4346 - categorical_accuracy: 0.3755
# Epoch 904/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3913 - categorical_accuracy: 0.4101
# Epoch 905/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3609 - categorical_accuracy: 0.4212
# Epoch 906/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3648 - categorical_accuracy: 0.4253
# Epoch 907/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4481 - categorical_accuracy: 0.3714
# Epoch 908/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.4015 - categorical_accuracy: 0.3887
# Epoch 909/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3957 - categorical_accuracy: 0.3943
# Epoch 910/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3947 - categorical_accuracy: 0.4167
# Epoch 911/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4160 - categorical_accuracy: 0.3841
# Epoch 912/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3889 - categorical_accuracy: 0.4167
# Epoch 913/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4021 - categorical_accuracy: 0.4090
# Epoch 914/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3871 - categorical_accuracy: 0.4106
# Epoch 915/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.3990 - categorical_accuracy: 0.3933
# Epoch 916/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3928 - categorical_accuracy: 0.4075
# Epoch 917/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4038 - categorical_accuracy: 0.3974
# Epoch 918/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3887 - categorical_accuracy: 0.4167
# Epoch 919/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3917 - categorical_accuracy: 0.3958
# Epoch 920/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3843 - categorical_accuracy: 0.4177
# Epoch 921/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4164 - categorical_accuracy: 0.3913
# Epoch 922/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4022 - categorical_accuracy: 0.3979
# Epoch 923/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4009 - categorical_accuracy: 0.4055
# Epoch 924/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4006 - categorical_accuracy: 0.4055
# Epoch 925/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3948 - categorical_accuracy: 0.3897
# Epoch 926/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3729 - categorical_accuracy: 0.4126
# Epoch 927/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.4007 - categorical_accuracy: 0.3902
# Epoch 928/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4068 - categorical_accuracy: 0.3897
# Epoch 929/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3846 - categorical_accuracy: 0.4116
# Epoch 930/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4223 - categorical_accuracy: 0.3892
# Epoch 931/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4009 - categorical_accuracy: 0.4055
# Epoch 932/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4046 - categorical_accuracy: 0.3908
# Epoch 933/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.4469 - categorical_accuracy: 0.3775
# Epoch 934/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4069 - categorical_accuracy: 0.3948
# Epoch 935/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4075 - categorical_accuracy: 0.3938
# Epoch 936/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4077 - categorical_accuracy: 0.3933
# Epoch 937/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3897 - categorical_accuracy: 0.4090
# Epoch 938/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3998 - categorical_accuracy: 0.4045
# Epoch 939/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4237 - categorical_accuracy: 0.3963
# Epoch 940/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4099 - categorical_accuracy: 0.3943
# Epoch 941/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3832 - categorical_accuracy: 0.3994
# Epoch 942/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3928 - categorical_accuracy: 0.4121
# Epoch 943/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.3833 - categorical_accuracy: 0.4085
# Epoch 944/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3790 - categorical_accuracy: 0.4009
# Epoch 945/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4084 - categorical_accuracy: 0.3994
# Epoch 946/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3993 - categorical_accuracy: 0.3943
# Epoch 947/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3754 - categorical_accuracy: 0.4055
# Epoch 948/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.4083 - categorical_accuracy: 0.3984
# Epoch 949/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4011 - categorical_accuracy: 0.3847
# Epoch 950/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3884 - categorical_accuracy: 0.3913
# Epoch 951/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3705 - categorical_accuracy: 0.4182
# Epoch 952/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4093 - categorical_accuracy: 0.3745
# Epoch 953/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.3931 - categorical_accuracy: 0.3872
# Epoch 954/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4016 - categorical_accuracy: 0.3948
# Epoch 955/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4120 - categorical_accuracy: 0.3928
# Epoch 956/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3683 - categorical_accuracy: 0.4080
# Epoch 957/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3964 - categorical_accuracy: 0.3943
# Epoch 958/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4040 - categorical_accuracy: 0.3933
# Epoch 959/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3699 - categorical_accuracy: 0.4106
# Epoch 960/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3878 - categorical_accuracy: 0.4101
# Epoch 961/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3569 - categorical_accuracy: 0.4187
# Epoch 962/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3963 - categorical_accuracy: 0.3984
# Epoch 963/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3978 - categorical_accuracy: 0.3908
# Epoch 964/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3965 - categorical_accuracy: 0.4024
# Epoch 965/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4010 - categorical_accuracy: 0.4024
# Epoch 966/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3830 - categorical_accuracy: 0.4014
# Epoch 967/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.3873 - categorical_accuracy: 0.3979
# Epoch 968/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3845 - categorical_accuracy: 0.3984
# Epoch 969/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3792 - categorical_accuracy: 0.3958
# Epoch 970/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3849 - categorical_accuracy: 0.4024
# Epoch 971/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3887 - categorical_accuracy: 0.3994
# Epoch 972/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3842 - categorical_accuracy: 0.4177
# Epoch 973/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4046 - categorical_accuracy: 0.3882
# Epoch 974/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.3875 - categorical_accuracy: 0.3989
# Epoch 975/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4120 - categorical_accuracy: 0.3897
# Epoch 976/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3909 - categorical_accuracy: 0.3999
# Epoch 977/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3859 - categorical_accuracy: 0.4055
# Epoch 978/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4114 - categorical_accuracy: 0.3847
# Epoch 979/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3626 - categorical_accuracy: 0.4131
# Epoch 980/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3915 - categorical_accuracy: 0.4116
# Epoch 981/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3942 - categorical_accuracy: 0.3938
# Epoch 982/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3842 - categorical_accuracy: 0.4116
# Epoch 983/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3871 - categorical_accuracy: 0.3943
# Epoch 984/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3938 - categorical_accuracy: 0.4090
# Epoch 985/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3779 - categorical_accuracy: 0.4040
# Epoch 986/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3968 - categorical_accuracy: 0.4024
# Epoch 987/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3886 - categorical_accuracy: 0.4055
# Epoch 988/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4081 - categorical_accuracy: 0.3887
# Epoch 989/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3830 - categorical_accuracy: 0.4029
# Epoch 990/1000
# 62/62 [==============================] - 0s 3ms/step - loss: 1.4047 - categorical_accuracy: 0.3923
# Epoch 991/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3999 - categorical_accuracy: 0.3943
# Epoch 992/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3964 - categorical_accuracy: 0.3902
# Epoch 993/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4020 - categorical_accuracy: 0.4065
# Epoch 994/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3796 - categorical_accuracy: 0.3999
# Epoch 995/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4031 - categorical_accuracy: 0.4014
# Epoch 996/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3798 - categorical_accuracy: 0.4162
# Epoch 997/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3838 - categorical_accuracy: 0.4141
# Epoch 998/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.4018 - categorical_accuracy: 0.4024
# Epoch 999/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3769 - categorical_accuracy: 0.3999
# Epoch 1000/1000
# 62/62 [==============================] - 0s 2ms/step - loss: 1.3758 - categorical_accuracy: 0.3953
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dropout_20 (Dropout)        (None, 1662)              0
#
#  dense_28 (Dense)            (None, 20)                33260
#
#  dropout_21 (Dropout)        (None, 20)                0
#
#  dense_29 (Dense)            (None, 10)                210
#
#  dense_30 (Dense)            (None, 6)                 66
#
# =================================================================
# Total params: 33,536
# Trainable params: 33,536
# Non-trainable params: 0
# _________________________________________________________________

# %%
yhat = model.predict(X_test)

ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

print(multilabel_confusion_matrix(ytrue, yhat))

print(accuracy_score(ytrue, yhat))
# Out:
# 16/16 [==============================] - 0s 798us/step
# [[[396   3]
#   [ 64  29]]
#
#  [[438   6]
#   [ 41   7]]
#
#  [[407   2]
#   [ 36  47]]
#
#  [[291 109]
#   [ 24  68]]
#
#  [[383  13]
#   [ 49  47]]
#
#  [[298 114]
#   [ 33  47]]]
# 0.49796747967479676

# %% [markdown]
# ## Real Time Visualisation

# %%
sequence = []
sentence = []
predictions = []
threshold = 0.6
# Select a webcam
cap = cv2.VideoCapture(0)

# Access mediapipe model
with mp_holistic.Holistic(
    min_detection_confidence=0.5, min_tracking_confidence=0.5
) as holistic:
    while cap.isOpened():
        # Read feed
        # ret is return value, frame is the image
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        draw_landmarks(image, results)

        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-int(sequence_length) :]

        if len(sequence) == int(sequence_length):
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(signs[np.argmax(res)])
            predictions.append(np.argmax(res))

            if np.unique(predictions[-10:])[0] == np.argmax(res):
                if res[np.argmax(res)] > threshold:

                    if len(sentence) > 0:
                        if signs[np.argmax(res)] != sentence[-1]:
                            sentence.append(signs[np.argmax(res)])
                    else:
                        sentence.append(signs[np.argmax(res)])

                if len(sentence) > 5:
                    sentence = sentence[-5:]

        cv2.rectangle(image, (0, 0), (640, 40), (245, 117, 16), -1)
        cv2.putText(
            image,
            " ".join(sentence),
            (3, 30),
            cv2.FONT_HERSHEY_SIMPLEX,
            1,
            (255, 255, 255),
            2,
            cv2.LINE_AA,
        )
        cv2.imshow("Sign Language Recognition", image)

        # Break using q
        if cv2.waitKey(10) & 0xFF == ord("q"):
            break

    # Release webcam and close windows
    cap.release()
    cv2.destroyAllWindows()
